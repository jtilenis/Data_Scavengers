# %%
import pandas as pd
import os
from pprint import pprint
import requests
import json
from config import api_key
import sys

# %%
#Made edits in excel, pulling back in
clean_hospital= pd.read_csv("Cleaned_Hospitals_v7.csv")
clean_hospital = clean_hospital.drop(columns=['Unnamed: 0'])
clean_hospital
# Out:
#                            Hospital name          City           County  \
# 0                    AdventHealth Gordon       Calhoun    Gordon County
# 1                    AdventHealth Murray    Chatsworth    Murray County
# 2             Archbold Memorial Hospital   Thomasville    Thomas County
# 3      Archbold - Brooks County Hospital       Quitman    Brooks County
# 4    Archbold - Mitchell County Hospital       Camilla  Mitchell County
# ..                                   ...           ...              ...
# 612                                  NaN         Wrens              NaN
# 613                                  NaN  Wrightsville              NaN
# 614                                  NaN    Yatesville              NaN
# 615                                  NaN  Young Harris              NaN
# 616                                  NaN       Zebulon              NaN
#
#      Acute Care Beds YearFounded   Affiliation  \
# 0                 69         NaN  AdventHealth
# 1                 29         NaN  AdventHealth
# 2                264        1925      Archbold
# 3                 25         NaN      Archbold
# 4                 25         NaN      Archbold
# ..               ...         ...           ...
# 612                0         NaN           NaN
# 613                0         NaN           NaN
# 614                0         NaN           NaN
# 615                0         NaN           NaN
# 616                0         NaN           NaN
#
#                               Notes                     Place ID  \
# 0          Formerly Gordon Hospital  ChIJfVjpjer9X4gRGK7NwGG_tbg
# 1    Formerly Murray Medical Center  ChIJ-U0scjndX4gRG-FoXnNaHI4
# 2                               NaN  ChIJsxblg8q17YgR8XXHSBDuObQ
# 3                               NaN  ChIJiyuklBp_7ogRmoGX5XNztMM
# 4                               NaN  ChIJswuXyhic7YgRuk38qsPrYt4
# ..                              ...                          ...
# 612                             NaN                          NaN
# 613                             NaN                          NaN
# 614                             NaN                          NaN
# 615                             NaN                          NaN
# 616                             NaN                          NaN
#
#      Hospital Latitude  Hospital Longtitude               Street Address  \
# 0            34.510205           -84.926304  1035 Red Bud Road Northeast
# 1            34.779956           -84.783038  707 Old Dalton Ellijay Road
# 2            30.825169           -83.972128            915 Gordon Avenue
# 3            30.795039           -83.559146       903 North Court Street
# 4            31.229773           -84.205317      90 East Stephens Street
# ..                 ...                  ...                          ...
# 612                NaN                  NaN                          NaN
# 613                NaN                  NaN                          NaN
# 614                NaN                  NaN                          NaN
# 615                NaN                  NaN                          NaN
# 616                NaN                  NaN                          NaN
#
#        State  Hospital Zip Code  \
# 0    Georgia            30701.0
# 1    Georgia            30705.0
# 2    Georgia            31792.0
# 3    Georgia            31643.0
# 4    Georgia            31730.0
# ..       ...                ...
# 612      NaN                NaN
# 613      NaN                NaN
# 614      NaN                NaN
# 615      NaN                NaN
# 616      NaN                NaN
#
#                                           Full Address  City Zip Code  \
# 0           1035 Red Bud Rd NE, Calhoun, GA 30701, USA        30702.0
# 1    707 Old Dalton Ellijay Rd, Chatsworth, GA 3070...        30705.0
# 2           915 Gordon Ave, Thomasville, GA 31792, USA        31776.5
# 3               903 N Court St, Quitman, GA 31643, USA        31643.0
# 4             90 E Stephens St, Camilla, GA 31730, USA        31730.0
# ..                                                 ...            ...
# 612                                                NaN        30833.0
# 613                                                NaN        31096.0
# 614                                                NaN        31097.0
# 615                                                NaN        30582.0
# 616                                                NaN        30295.0
#
#      City Latitude  City Longtitude  Median Income  Population  Joined
# 0        34.487833       -84.850071          24110       40820   False
# 1        34.753129       -84.775020          24457       33460   False
# 2        30.862504       -83.928812          22498       20703   False
# 3        30.783639       -83.553430          24644        9062   False
# 4        31.209854       -84.236670          21584        8419   False
# ..             ...              ...            ...         ...     ...
# 612      33.200325       -82.376250          18634        3065    True
# 613      32.717320       -82.689260          20232        7046    True
# 614      32.912207       -84.148120          27000        1656    True
# 615      34.954638       -83.864840          15867        5038    True
# 616      33.101705       -84.312520          31654        4352    True
#
# [617 rows x 20 columns]

# %%
hospital_count = clean_hospital.groupby[()'City')('Hospital name').count()
hospital_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-666aaa18f597> in <module>
# ----> 1 hospital_count = clean_hospital.groupby('City')('Hospital name').count()
#       2 hospital_count
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
# hospital_count = hospital_count.loc[(hospital_count['Hospital name'] >= 0)]
# hospital_count
# census_cities = census_cities.loc[(census_cities['census_cities_old'] == 'Donalsonville')]
# Out:
# Empty DataFrame
# Columns: [Hospital name, County, Acute Care Beds, YearFounded, Affiliation, Notes, Place ID, Hospital Latitude, Hospital Longtitude, Street Address, State, Hospital Zip Code, Full Address, City Zip Code, City Latitude, City Longtitude, Median Income, Population, Joined]
# Index: []
