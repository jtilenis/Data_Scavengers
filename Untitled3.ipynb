# %%
import pandas as pd
import os
from pprint import pprint
import requests
import json
from config import api_key
import sys

# %%
#Made edits in excel, pulling back in
hospital = pd.read_csv("Cleaned_Hospitalsv2.csv")
hospital
# Out:
#      Unnamed: 0                          Hospital name                  City  \
# 0             0                    AdventHealth Gordon               Calhoun
# 1             1                    AdventHealth Murray            Chatsworth
# 2             2             Archbold Memorial Hospital           Thomasville
# 3             3      Archbold - Brooks County Hospital               Quitman
# 4             4      Archbold - Grady General Hospital                 Cairo
# ..          ...                                    ...                   ...
# 130         109                   St. Francis Hospital  Greater Valley Brook
# 131         110                  St. Joseph's Hospital      Perimeter Center
# 132         111                    St. Mary's Hospital      Perimeter Center
# 133         126        Wellstar Atlanta Medical Center       Old Fourth Ward
# 134         127  WellStar Atlanta Medical Center South            River Park
#
# ...

# %%
hospital_fix = hospital.loc[(hospital['State'] != 'Georgia')]
hospital_fix
# Out:
#      Unnamed: 0                                      Hospital name  \
# 115           6  Augusta University Children's Hospital of Georgia
# 116           7                  Augusta University Medical Center
# 117          12                                   Candler Hospital
# 118          17   Children's Healthcare of Atlanta Hughes Spalding
# 119          18     Children's Healthcare of Atlanta Scottish Rite
# 120          30                            Eastside Medical Center
# 121          37                      Emory Saint Joseph's Hospital
# 122          39                  Emory University Hospital Midtown
# 123          43                           Fannin Regional Hospital
# 124          47                            Grady Memorial Hospital
# 125          48                           Habersham Medical Center
# 126          56                                 Jefferson Hospital
# 127          63          Memorial Health University Medical Center
# ...

# %%
hospital_fix_county = hospital_fix
hospital_fix_county['new_city'] = ""
hospital_fix_county['new_county'] = ""
hospital_fix_county['new_state'] = "Georgia"
hospital_fix_county
# Out:
# C:\Users\u14849\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\u14849\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\u14849\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
sys.setrecursionlimit(10**6) 

hospital_fix.dtypes

hospital_fix_county['new_city'] = hospital_fix_county['County']
hospital_fix_county['new_county'] = hospital_fix_county['State']
hospital_fix_county

# hospital_fix_county = hospital_fix_county['new_city'] = hospital_fix_county['County']
# hospital_fix_county
# Out:
# C:\Users\u14849\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\u14849\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Unnamed: 0                                      Hospital name  \
# 115           6  Augusta University Children's Hospital of Georgia
# 116           7                  Augusta University Medical Center
# ...

# %%
hospital_clean = hospital.loc[(hospital['State'] == 'Georgia')]
hospital_clean
# Out:
#      Unnamed: 0                         Hospital name         City  \
# 0             0                   AdventHealth Gordon      Calhoun
# 1             1                   AdventHealth Murray   Chatsworth
# 2             2            Archbold Memorial Hospital  Thomasville
# 3             3     Archbold - Brooks County Hospital      Quitman
# 4             4     Archbold - Grady General Hospital        Cairo
# ..          ...                                   ...          ...
# 110         132            WellStar Paulding Hospital        Hiram
# 111         133   WellStar Spalding Regional Hospital      Griffin
# 112         134        WellStar Sylvan Grove Hospital      Jackson
# 113         135  WellStar West Georgia Medical Center     LaGrange
# 114         136               Wills Memorial Hospital   Washington
#
#               County  Acute Care Beds YearFounded   Affiliation  \
# 0      Gordon County             69.0         NaN  AdventHealth
# ...
