# %%
import requests
import json
import requests
from pprint import pprint
import pandas as pd
import gmaps
import matplotlib.pyplot as plt

# %%
# Store filepath in a variable
hospital_data = "Cleaned_Hospitals_v4.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
hospital_df = pd.read_csv(hospital_data, encoding="ISO-8859-1")
hospital_df
# Out:
#      Unnamed: 0                        Hospital name         City  \
# 0             0                  AdventHealth Gordon      Calhoun
# 1             1                  AdventHealth Murray   Chatsworth
# 2             2           Archbold Memorial Hospital  Thomasville
# 3             3    Archbold - Brooks County Hospital      Quitman
# 4             5  Archbold - Mitchell County Hospital      Camilla
# ..          ...                                  ...          ...
# 118         130            Piedmont Atlanta Hospital      Atlanta
# 119         132                 St. Francis Hospital      Decatur
# 120         133                St. Joseph's Hospital      Atlanta
# 121         134                  St. Mary's Hospital      Atlanta
# 122         135      Wellstar Atlanta Medical Center      Atlanta
#
#               County Acute Care Beds YearFounded   Affiliation  \
# 0      Gordon County              69         NaN  AdventHealth
# 1      Murray County              29         NaN  AdventHealth
# 2      Thomas County             264        1925      Archbold
# 3      Brooks County              25         NaN      Archbold
# 4    Mitchell County              25         NaN      Archbold
# ..               ...             ...         ...           ...
# 118    Fulton County             498         NaN      Piedmont
# 119    DeKalb County             360        1950         Emory
# 120    Fulton County             330        1875         SJCHS
# 121    Fulton County             170         NaN    St. Mary's
# 122    Fulton County             460        1901      WellStar
#
#                               Notes                     Place ID   Latitude  \
# 0          Formerly Gordon Hospital  ChIJfVjpjer9X4gRGK7NwGG_tbg  34.510205
# 1    Formerly Murray Medical Center  ChIJ-U0scjndX4gRG-FoXnNaHI4  34.779956
# 2                               NaN  ChIJsxblg8q17YgR8XXHSBDuObQ  30.825169
# 3                               NaN  ChIJiyuklBp_7ogRmoGX5XNztMM  30.795039
# 4                               NaN  ChIJswuXyhic7YgRuk38qsPrYt4  31.229773
# ..                              ...                          ...        ...
# 118                             NaN  ChIJZ2L4-KkF9YgRtyK-3YkszI8  33.808755
# 119                             NaN  ChIJrzBX-3gH9YgRpeQf21LpXF4  33.795761
# 120                             NaN  ChIJW3epPTQJ9YgRxf9a5U20qNg  33.908422
# 121                             NaN  ChIJW3epPTQJ9YgRxf9a5U20qNg  33.908422
# 122                             NaN  ChIJH9RgbwsE9YgRCefukbDOojs  33.762907
#
#      Longtitude                              Street Address    State  \
# 0    -84.926304                 1035 Red Bud Road Northeast  Georgia
# 1    -84.783038                 707 Old Dalton Ellijay Road  Georgia
# 2    -83.972128                           915 Gordon Avenue  Georgia
# 3    -83.559146                      903 North Court Street  Georgia
# 4    -84.205317                     90 East Stephens Street  Georgia
# ..          ...                                         ...      ...
# 118  -84.395557           Peachtree Road Northwest Buckhead  Georgia
# 119  -84.276954  Dekalb Industrial Way Greater Valley Brook  Georgia
# 120  -84.349851    Peachtree Dunwoody Road Perimeter Center  Georgia
# 121  -84.349851    Peachtree Dunwoody Road Perimeter Center  Georgia
# 122  -84.372961     Parkway Drive Northeast Old Fourth Ward  Georgia
#
#      Zip Code                                       Full Address  \
# 0     30701.0         1035 Red Bud Rd NE, Calhoun, GA 30701, USA
# 1     30705.0  707 Old Dalton Ellijay Rd, Chatsworth, GA 3070...
# 2     31792.0         915 Gordon Ave, Thomasville, GA 31792, USA
# 3     31643.0             903 N Court St, Quitman, GA 31643, USA
# 4     31730.0           90 E Stephens St, Camilla, GA 31730, USA
# ..        ...                                                ...
# 118   30309.0       1968 Peachtree Rd NW, Atlanta, GA 30309, USA
# 119   30033.0  625 Dekalb Industrial Way, Decatur, GA 30033, USA
# 120   30342.0  5665 Peachtree Dunwoody Rd, Atlanta, GA 30342,...
# 121   30342.0  5665 Peachtree Dunwoody Rd, Atlanta, GA 30342,...
# 122   30312.0          303 Parkway Dr NE, Atlanta, GA 30312, USA
#
#      Median Income  Population
# 0            24110       40820
# 1            24457       33460
# 2            22498       20703
# 3            24644        9062
# 4            21584        8419
# ..             ...         ...
# 118      -21943664       25919
# 119          33401       37842
# 120      -21943664       25919
# 121      -21943664       25919
# 122      -21943664       25919
#
# [123 rows x 17 columns]
