# %%
import pandas as pd
import os
from pprint import pprint
import requests
import json
from config import api_key

# %%
# filepath = "sattest.py"
# with open(filepath, 'r') as text:
#       print(text)

# print(api_key)

# url = "http://api.census.gov/data/2017/popproj/pop?get=POP,YEAR&for=us:1&key="+ api_key

url = "http://api.census.gov/data/2019/pep/population?get=COUNTY,DATE_CODE,DATE_DESC,DENSITY,POP,NAME,STATE&for=region:*&key=" + api_key



response = requests.get(url)

response_json = response.json()
pprint(response_json)
# Out:
# [['COUNTY',
#   'DATE_CODE',
#   'DATE_DESC',
#   'DENSITY',
#   'POP',
#   'NAME',
#   'STATE',
#   'region'],
#  [None,
#   '1',
#   '4/1/2010 Census population',
#   None,
#   '114555744',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '2',
#   '4/1/2010 population estimates base',
#   None,
#   '114563030',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '3',
#   '7/1/2010 population estimate',
#   None,
#   '114866680',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '4',
#   '7/1/2011 population estimate',
#   None,
#   '116006522',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '5',
#   '7/1/2012 population estimate',
#   None,
#   '117241208',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '6',
#   '7/1/2013 population estimate',
#   None,
#   '118364400',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '7',
#   '7/1/2014 population estimate',
#   None,
#   '119624037',
#   'South Region',
#   None,
#   '3'],
#  [None,
#   '8',
# ...
